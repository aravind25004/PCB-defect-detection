# %%
import os
import cv2
import numpy as np
import xml.etree.ElementTree as ET
import shutil

# %%
import os
import cv2
import shutil
import numpy as np
import xml.etree.ElementTree as ET

def create_full_dataset(root_dir, output_dir, class_mapping):
    """
    Create dataset with mirrored structure for both images and masks
    with strict class name validation
    """
    # Define paths
    input_images = os.path.join(root_dir, "PCB_DATASET", "images")
    annotations_base = os.path.join(root_dir, "PCB_DATASET", "Annotations")
    
    # Create output directories
    output_images = os.path.join(output_dir, "images")
    output_masks = os.path.join(output_dir, "masks")
    os.makedirs(output_images, exist_ok=True)
    os.makedirs(output_masks, exist_ok=True)

    # Get valid class names for error messages
    valid_classes = list(class_mapping.keys())
    
    # Process each defect category
    defects = ["Missing_hole", "Mouse_bite", "Open_circuit", 
              "Short", "Spur", "Spurious_copper"]

    for defect in defects:
        print(f"\nProcessing {defect}...")
        
        # Create output subdirectories
        img_defect_dir = os.path.join(output_images, defect)
        mask_defect_dir = os.path.join(output_masks, defect)
        os.makedirs(img_defect_dir, exist_ok=True)
        os.makedirs(mask_defect_dir, exist_ok=True)

        # Get input paths
        input_img_dir = os.path.join(input_images, defect)
        input_xml_dir = os.path.join(annotations_base, defect)

        # Process each image
        for img_file in os.listdir(input_img_dir):
            if not img_file.lower().endswith(('.png', '.jpg', '.jpeg')):
                continue

            base_name = os.path.splitext(img_file)[0]
            img_path = os.path.join(input_img_dir, img_file)
            xml_path = os.path.join(input_xml_dir, f"{base_name}.xml")
            
            # Skip if XML is missing
            if not os.path.exists(xml_path):
                print(f"Warning: Missing XML for {img_file}")
                continue

            try:
                # Copy image to output directory
                output_img_path = os.path.join(img_defect_dir, img_file)
                shutil.copy2(img_path, output_img_path)

                # Generate mask
                img = cv2.imread(img_path)
                h, w = img.shape[:2]
                mask = np.zeros((h, w), dtype=np.uint8)

                tree = ET.parse(xml_path)
                root = tree.getroot()

                for obj in root.findall('object'):
                    # Validate class name
                    class_name = obj.find('name').text.strip().lower()
                    
                    if class_name not in class_mapping:
                        raise ValueError(
                            f"Invalid class '{class_name}' in {img_file}\n"
                            f"Valid classes: {valid_classes}\n"
                            f"XML path: {xml_path}"
                        )
                    
                    class_id = class_mapping[class_name]

                    # Process bounding box
                    bndbox = obj.find('bndbox')
                    try:
                        xmin = int(bndbox.find('xmin').text)
                        ymin = int(bndbox.find('ymin').text)
                        xmax = int(bndbox.find('xmax').text)
                        ymax = int(bndbox.find('ymax').text)
                    except AttributeError:
                        print(f"Invalid bndbox in {img_file}")
                        continue

                    # Validate coordinates
                    xmin = max(0, min(xmin, w-1))
                    xmax = max(0, min(xmax, w-1))
                    ymin = max(0, min(ymin, h-1))
                    ymax = max(0, min(ymax, h-1))
                    
                    # Draw rectangle with class ID
                    cv2.rectangle(mask, (xmin, ymin), (xmax, ymax), class_id, -1)

                # Verify and save mask
                unique_values = np.unique(mask)
                print(f"Processed {img_file} - Unique mask values: {unique_values}")
                
                mask_path = os.path.join(mask_defect_dir, f"{base_name}.png")
                cv2.imwrite(mask_path, mask)

            except Exception as e:
                print(f"Error processing {img_file}: {str(e)}")
                raise  # Re-raise the error to stop execution

# Class mapping with lowercase keys
CLASS_MAPPING = {
    "missing_hole": 1,
    "mouse_bite": 2,
    "open_circuit": 3,
    "short": 4,
    "spur": 5,
    "spurious_copper": 6
}

# Usage
create_full_dataset(
    root_dir="/kaggle/input/pcb-defects",
    output_dir="/kaggle/working/pcb_dataset",
    class_mapping=CLASS_MAPPING
)
# Out:
# Processing Missing_hole...
# Processed 01_missing_hole_01.jpg - Unique mask values: [0 1]
# Processed 04_missing_hole_01.jpg - Unique mask values: [0 1]
# Processed 01_missing_hole_17.jpg - Unique mask values: [0 1]
# Processed 04_missing_hole_12.jpg - Unique mask values: [0 1]
# Processed 07_missing_hole_06.jpg - Unique mask values: [0 1]
# Processed 12_missing_hole_08.jpg - Unique mask values: [0 1]
# Processed 04_missing_hole_10.jpg - Unique mask values: [0 1]
# Processed 01_missing_hole_02.jpg - Unique mask values: [0 1]
# Processed 08_missing_hole_06.jpg - Unique mask values: [0 1]
# Processed 04_missing_hole_06.jpg - Unique mask values: [0 1]
# Processed 06_missing_hole_08.jpg - Unique mask values: [0 1]
# Processed 01_missing_hole_20.jpg - Unique mask values: [0 1]
# Processed 12_missing_hole_09.jpg - Unique mask values: [0 1]
# Processed 04_missing_hole_04.jpg - Unique mask values: [0 1]
# Processed 01_missing_hole_08.jpg - Unique mask values: [0 1]
# Processed 07_missing_hole_08.jpg - Unique mask values: [0 1]
# Processed 01_missing_hole_16.jpg - Unique mask values: [0 1]
# Processed 07_missing_hole_05.jpg - Unique mask values: [0 1]
# Processed 07_missing_hole_10.jpg - Unique mask values: [0 1]
# Processed 01_missing_hole_03.jpg - Unique mask values: [0 1]
# Processed 10_missing_hole_05.jpg - Unique mask values: [0 1]
# Processed 01_missing_hole_05.jpg - Unique mask values: [0 1]
# Processed 11_missing_hole_06.jpg - Unique mask values: [0 1]
# Processed 06_missing_hole_10.jpg - Unique mask values: [0 1]
# Processed 05_missing_hole_10.jpg - Unique mask values: [0 1]
# Processed 09_missing_hole_04.jpg - Unique mask values: [0 1]
# Processed 10_missing_hole_03.jpg - Unique mask values: [0 1]
# Processed 10_missing_hole_01.jpg - Unique mask values: [0 1]
# Processed 08_missing_hole_10.jpg - Unique mask values: [0 1]
# Processed 06_missing_hole_07.jpg - Unique mask values: [0 1]
# Processed 04_missing_hole_11.jpg - Unique mask values: [0 1]
# Processed 07_missing_hole_07.jpg - Unique mask values: [0 1]
# Processed 09_missing_hole_09.jpg - Unique mask values: [0 1]
# Processed 11_missing_hole_04.jpg - Unique mask values: [0 1]
# Processed 07_missing_hole_04.jpg - Unique mask values: [0 1]
# Processed 11_missing_hole_03.jpg - Unique mask values: [0 1]
# Processed 04_missing_hole_19.jpg - Unique mask values: [0 1]
# Processed 01_missing_hole_19.jpg - Unique mask values: [0 1]
# Processed 12_missing_hole_01.jpg - Unique mask values: [0 1]
# Processed 01_missing_hole_15.jpg - Unique mask values: [0 1]
# Processed 11_missing_hole_02.jpg - Unique mask values: [0 1]
# Processed 05_missing_hole_01.jpg - Unique mask values: [0 1]
# Processed 04_missing_hole_17.jpg - Unique mask values: [0 1]
# Processed 12_missing_hole_02.jpg - Unique mask values: [0 1]
# Processed 09_missing_hole_01.jpg - Unique mask values: [0 1]
# Processed 05_missing_hole_06.jpg - Unique mask values: [0 1]
# Processed 05_missing_hole_07.jpg - Unique mask values: [0 1]
# Processed 04_missing_hole_07.jpg - Unique mask values: [0 1]
# Processed 09_missing_hole_05.jpg - Unique mask values: [0 1]
# Processed 12_missing_hole_04.jpg - Unique mask values: [0 1]
# Processed 04_missing_hole_09.jpg - Unique mask values: [0 1]
# Processed 01_missing_hole_04.jpg - Unique mask values: [0 1]
# Processed 09_missing_hole_10.jpg - Unique mask values: [0 1]
# Processed 12_missing_hole_03.jpg - Unique mask values: [0 1]
# Processed 05_missing_hole_03.jpg - Unique mask values: [0 1]
# Processed 04_missing_hole_16.jpg - Unique mask values: [0 1]
# Processed 12_missing_hole_05.jpg - Unique mask values: [0 1]
# Processed 09_missing_hole_08.jpg - Unique mask values: [0 1]
# Processed 04_missing_hole_03.jpg - Unique mask values: [0 1]
# Processed 08_missing_hole_03.jpg - Unique mask values: [0 1]
# Processed 06_missing_hole_09.jpg - Unique mask values: [0 1]
# Processed 06_missing_hole_02.jpg - Unique mask values: [0 1]
# Processed 01_missing_hole_11.jpg - Unique mask values: [0 1]
# Processed 10_missing_hole_04.jpg - Unique mask values: [0 1]
# Processed 11_missing_hole_09.jpg - Unique mask values: [0 1]
# Processed 11_missing_hole_05.jpg - Unique mask values: [0 1]
# Processed 05_missing_hole_02.jpg - Unique mask values: [0 1]
# Processed 08_missing_hole_09.jpg - Unique mask values: [0 1]
# Processed 01_missing_hole_10.jpg - Unique mask values: [0 1]
# Processed 11_missing_hole_08.jpg - Unique mask values: [0 1]
# Processed 06_missing_hole_04.jpg - Unique mask values: [0 1]
# Processed 05_missing_hole_05.jpg - Unique mask values: [0 1]
# Processed 01_missing_hole_18.jpg - Unique mask values: [0 1]
# Processed 09_missing_hole_03.jpg - Unique mask values: [0 1]
# Processed 11_missing_hole_07.jpg - Unique mask values: [0 1]
# Processed 07_missing_hole_01.jpg - Unique mask values: [0 1]
# Processed 01_missing_hole_07.jpg - Unique mask values: [0 1]
# Processed 01_missing_hole_12.jpg - Unique mask values: [0 1]
# Processed 07_missing_hole_09.jpg - Unique mask values: [0 1]
# Processed 08_missing_hole_04.jpg - Unique mask values: [0 1]
# Processed 08_missing_hole_07.jpg - Unique mask values: [0 1]
# Processed 01_missing_hole_13.jpg - Unique mask values: [0 1]
# Processed 04_missing_hole_15.jpg - Unique mask values: [0 1]
# Processed 04_missing_hole_13.jpg - Unique mask values: [0 1]
# Processed 01_missing_hole_14.jpg - Unique mask values: [0 1]
# Processed 08_missing_hole_08.jpg - Unique mask values: [0 1]
# Processed 04_missing_hole_20.jpg - Unique mask values: [0 1]
# Processed 06_missing_hole_03.jpg - Unique mask values: [0 1]
# Processed 11_missing_hole_01.jpg - Unique mask values: [0 1]
# Processed 04_missing_hole_02.jpg - Unique mask values: [0 1]
# Processed 06_missing_hole_05.jpg - Unique mask values: [0 1]
# Processed 10_missing_hole_02.jpg - Unique mask values: [0 1]
# Processed 09_missing_hole_06.jpg - Unique mask values: [0 1]
# Processed 09_missing_hole_02.jpg - Unique mask values: [0 1]
# Processed 06_missing_hole_06.jpg - Unique mask values: [0 1]
# Processed 05_missing_hole_04.jpg - Unique mask values: [0 1]
# Processed 01_missing_hole_09.jpg - Unique mask values: [0 1]
# Processed 12_missing_hole_10.jpg - Unique mask values: [0 1]
# Processed 01_missing_hole_06.jpg - Unique mask values: [0 1]
# Processed 09_missing_hole_07.jpg - Unique mask values: [0 1]
# Processed 04_missing_hole_14.jpg - Unique mask values: [0 1]
# Processed 04_missing_hole_18.jpg - Unique mask values: [0 1]
# Processed 11_missing_hole_10.jpg - Unique mask values: [0 1]
# Processed 05_missing_hole_09.jpg - Unique mask values: [0 1]
# Processed 08_missing_hole_02.jpg - Unique mask values: [0 1]
# Processed 04_missing_hole_05.jpg - Unique mask values: [0 1]
# Processed 12_missing_hole_06.jpg - Unique mask values: [0 1]
# Processed 08_missing_hole_05.jpg - Unique mask values: [0 1]
# Processed 06_missing_hole_01.jpg - Unique mask values: [0 1]
# Processed 08_missing_hole_01.jpg - Unique mask values: [0 1]
# Processed 05_missing_hole_08.jpg - Unique mask values: [0 1]
# Processed 07_missing_hole_02.jpg - Unique mask values: [0 1]
# Processed 07_missing_hole_03.jpg - Unique mask values: [0 1]
# Processed 12_missing_hole_07.jpg - Unique mask values: [0 1]
# Processed 04_missing_hole_08.jpg - Unique mask values: [0 1]
#
# Processing Mouse_bite...
# Processed 01_mouse_bite_20.jpg - Unique mask values: [0 2]
# Processed 04_mouse_bite_16.jpg - Unique mask values: [0 2]
# Processed 12_mouse_bite_06.jpg - Unique mask values: [0 2]
# Processed 04_mouse_bite_11.jpg - Unique mask values: [0 2]
# Processed 06_mouse_bite_04.jpg - Unique mask values: [0 2]
# Processed 12_mouse_bite_09.jpg - Unique mask values: [0 2]
# Processed 08_mouse_bite_10.jpg - Unique mask values: [0 2]
# Processed 04_mouse_bite_15.jpg - Unique mask values: [0 2]
# Processed 08_mouse_bite_07.jpg - Unique mask values: [0 2]
# Processed 09_mouse_bite_02.jpg - Unique mask values: [0 2]
# Processed 09_mouse_bite_08.jpg - Unique mask values: [0 2]
# Processed 07_mouse_bite_01.jpg - Unique mask values: [0 2]
# Processed 01_mouse_bite_03.jpg - Unique mask values: [0 2]
# Processed 05_mouse_bite_04.jpg - Unique mask values: [0 2]
# Processed 09_mouse_bite_10.jpg - Unique mask values: [0 2]
# Processed 07_mouse_bite_09.jpg - Unique mask values: [0 2]
# Processed 07_mouse_bite_08.jpg - Unique mask values: [0 2]
# Processed 05_mouse_bite_03.jpg - Unique mask values: [0 2]
# Processed 08_mouse_bite_02.jpg - Unique mask values: [0 2]
# Processed 06_mouse_bite_03.jpg - Unique mask values: [0 2]
# Processed 05_mouse_bite_07.jpg - Unique mask values: [0 2]
# Processed 06_mouse_bite_02.jpg - Unique mask values: [0 2]
# Processed 07_mouse_bite_07.jpg - Unique mask values: [0 2]
# Processed 07_mouse_bite_03.jpg - Unique mask values: [0 2]
# Processed 08_mouse_bite_05.jpg - Unique mask values: [0 2]
# Processed 04_mouse_bite_20.jpg - Unique mask values: [0 2]
# Processed 06_mouse_bite_06.jpg - Unique mask values: [0 2]
# Processed 07_mouse_bite_10.jpg - Unique mask values: [0 2]
# Processed 01_mouse_bite_16.jpg - Unique mask values: [0 2]
# Processed 07_mouse_bite_02.jpg - Unique mask values: [0 2]
# Processed 06_mouse_bite_09.jpg - Unique mask values: [0 2]
# Processed 11_mouse_bite_02.jpg - Unique mask values: [0 2]
# Processed 10_mouse_bite_01.jpg - Unique mask values: [0 2]
# Processed 09_mouse_bite_01.jpg - Unique mask values: [0 2]
# Processed 11_mouse_bite_10.jpg - Unique mask values: [0 2]
# Processed 06_mouse_bite_01.jpg - Unique mask values: [0 2]
# Processed 05_mouse_bite_06.jpg - Unique mask values: [0 2]
# Processed 11_mouse_bite_04.jpg - Unique mask values: [0 2]
# Processed 10_mouse_bite_03.jpg - Unique mask values: [0 2]
# Processed 01_mouse_bite_13.jpg - Unique mask values: [0 2]
# Processed 09_mouse_bite_05.jpg - Unique mask values: [0 2]
# Processed 05_mouse_bite_02.jpg - Unique mask values: [0 2]
# Processed 09_mouse_bite_07.jpg - Unique mask values: [0 2]
# Processed 05_mouse_bite_09.jpg - Unique mask values: [0 2]
# Processed 07_mouse_bite_06.jpg - Unique mask values: [0 2]
# Processed 10_mouse_bite_05.jpg - Unique mask values: [0 2]
# Processed 07_mouse_bite_04.jpg - Unique mask values: [0 2]
# Processed 01_mouse_bite_09.jpg - Unique mask values: [0 2]
# Processed 04_mouse_bite_03.jpg - Unique mask values: [0 2]
# Processed 04_mouse_bite_05.jpg - Unique mask values: [0 2]
# Processed 01_mouse_bite_19.jpg - Unique mask values: [0 2]
# Processed 08_mouse_bite_03.jpg - Unique mask values: [0 2]
# Processed 11_mouse_bite_05.jpg - Unique mask values: [0 2]
# Processed 04_mouse_bite_14.jpg - Unique mask values: [0 2]
# Processed 04_mouse_bite_12.jpg - Unique mask values: [0 2]
# Processed 01_mouse_bite_05.jpg - Unique mask values: [0 2]
# Processed 01_mouse_bite_07.jpg - Unique mask values: [0 2]
# Processed 01_mouse_bite_08.jpg - Unique mask values: [0 2]
# Processed 11_mouse_bite_09.jpg - Unique mask values: [0 2]
# Processed 12_mouse_bite_01.jpg - Unique mask values: [0 2]
# Processed 11_mouse_bite_06.jpg - Unique mask values: [0 2]
# Processed 01_mouse_bite_11.jpg - Unique mask values: [0 2]
# Processed 06_mouse_bite_05.jpg - Unique mask values: [0 2]
# Processed 12_mouse_bite_07.jpg - Unique mask values: [0 2]
# Processed 09_mouse_bite_06.jpg - Unique mask values: [0 2]
# Processed 01_mouse_bite_10.jpg - Unique mask values: [0 2]
# Processed 09_mouse_bite_04.jpg - Unique mask values: [0 2]
# Processed 08_mouse_bite_09.jpg - Unique mask values: [0 2]
# Processed 04_mouse_bite_07.jpg - Unique mask values: [0 2]
# Processed 04_mouse_bite_08.jpg - Unique mask values: [0 2]
# Processed 12_mouse_bite_10.jpg - Unique mask values: [0 2]
# Processed 01_mouse_bite_12.jpg - Unique mask values: [0 2]
# Processed 05_mouse_bite_01.jpg - Unique mask values: [0 2]
# Processed 08_mouse_bite_06.jpg - Unique mask values: [0 2]
# Processed 01_mouse_bite_02.jpg - Unique mask values: [0 2]
# Processed 05_mouse_bite_10.jpg - Unique mask values: [0 2]
# Processed 01_mouse_bite_14.jpg - Unique mask values: [0 2]
# Processed 04_mouse_bite_02.jpg - Unique mask values: [0 2]
# Processed 04_mouse_bite_04.jpg - Unique mask values: [0 2]
# Processed 08_mouse_bite_01.jpg - Unique mask values: [0 2]
# Processed 08_mouse_bite_08.jpg - Unique mask values: [0 2]
# Processed 05_mouse_bite_05.jpg - Unique mask values: [0 2]
# Processed 01_mouse_bite_04.jpg - Unique mask values: [0 2]
# Processed 11_mouse_bite_01.jpg - Unique mask values: [0 2]
# Processed 11_mouse_bite_08.jpg - Unique mask values: [0 2]
# Processed 12_mouse_bite_03.jpg - Unique mask values: [0 2]
# Processed 01_mouse_bite_17.jpg - Unique mask values: [0 2]
# Processed 04_mouse_bite_10.jpg - Unique mask values: [0 2]
# Processed 08_mouse_bite_04.jpg - Unique mask values: [0 2]
# Processed 01_mouse_bite_18.jpg - Unique mask values: [0 2]
# Processed 05_mouse_bite_08.jpg - Unique mask values: [0 2]
# Processed 12_mouse_bite_08.jpg - Unique mask values: [0 2]
# Processed 01_mouse_bite_15.jpg - Unique mask values: [0 2]
# Processed 07_mouse_bite_05.jpg - Unique mask values: [0 2]
# Processed 01_mouse_bite_06.jpg - Unique mask values: [0 2]
# Processed 11_mouse_bite_07.jpg - Unique mask values: [0 2]
# Processed 11_mouse_bite_03.jpg - Unique mask values: [0 2]
# Processed 04_mouse_bite_18.jpg - Unique mask values: [0 2]
# Processed 12_mouse_bite_05.jpg - Unique mask values: [0 2]
# Processed 06_mouse_bite_07.jpg - Unique mask values: [0 2]
# Processed 06_mouse_bite_10.jpg - Unique mask values: [0 2]
# Processed 04_mouse_bite_17.jpg - Unique mask values: [0 2]
# Processed 04_mouse_bite_13.jpg - Unique mask values: [0 2]
# Processed 01_mouse_bite_01.jpg - Unique mask values: [0 2]
# Processed 04_mouse_bite_01.jpg - Unique mask values: [0 2]
# Processed 09_mouse_bite_09.jpg - Unique mask values: [0 2]
# Processed 04_mouse_bite_09.jpg - Unique mask values: [0 2]
# Processed 09_mouse_bite_03.jpg - Unique mask values: [0 2]
# Processed 12_mouse_bite_04.jpg - Unique mask values: [0 2]
# Processed 06_mouse_bite_08.jpg - Unique mask values: [0 2]
# Processed 10_mouse_bite_04.jpg - Unique mask values: [0 2]
# Processed 12_mouse_bite_02.jpg - Unique mask values: [0 2]
# Processed 10_mouse_bite_02.jpg - Unique mask values: [0 2]
# Processed 04_mouse_bite_06.jpg - Unique mask values: [0 2]
# Processed 04_mouse_bite_19.jpg - Unique mask values: [0 2]
#
# Processing Open_circuit...
# Processed 07_open_circuit_07.jpg - Unique mask values: [0 3]
# Processed 01_open_circuit_20.jpg - Unique mask values: [0 3]
# Processed 10_open_circuit_04.jpg - Unique mask values: [0 3]
# Processed 09_open_circuit_09.jpg - Unique mask values: [0 3]
# Processed 08_open_circuit_10.jpg - Unique mask values: [0 3]
# Processed 05_open_circuit_01.jpg - Unique mask values: [0 3]
# Processed 08_open_circuit_03.jpg - Unique mask values: [0 3]
# Processed 04_open_circuit_07.jpg - Unique mask values: [0 3]
# Processed 04_open_circuit_20.jpg - Unique mask values: [0 3]
# Processed 09_open_circuit_04.jpg - Unique mask values: [0 3]
# Processed 11_open_circuit_09.jpg - Unique mask values: [0 3]
# Processed 01_open_circuit_01.jpg - Unique mask values: [0 3]
# Processed 01_open_circuit_11.jpg - Unique mask values: [0 3]
# Processed 04_open_circuit_18.jpg - Unique mask values: [0 3]
# Processed 11_open_circuit_06.jpg - Unique mask values: [0 3]
# Processed 11_open_circuit_05.jpg - Unique mask values: [0 3]
# Processed 05_open_circuit_07.jpg - Unique mask values: [0 3]
# Processed 04_open_circuit_14.jpg - Unique mask values: [0 3]
# Processed 06_open_circuit_05.jpg - Unique mask values: [0 3]
# Processed 09_open_circuit_03.jpg - Unique mask values: [0 3]
# Processed 07_open_circuit_06.jpg - Unique mask values: [0 3]
# Processed 07_open_circuit_04.jpg - Unique mask values: [0 3]
# Processed 07_open_circuit_03.jpg - Unique mask values: [0 3]
# Processed 04_open_circuit_11.jpg - Unique mask values: [0 3]
# Processed 06_open_circuit_09.jpg - Unique mask values: [0 3]
# Processed 12_open_circuit_07.jpg - Unique mask values: [0 3]
# Processed 12_open_circuit_05.jpg - Unique mask values: [0 3]
# Processed 01_open_circuit_18.jpg - Unique mask values: [0 3]
# Processed 07_open_circuit_08.jpg - Unique mask values: [0 3]
# Processed 09_open_circuit_01.jpg - Unique mask values: [0 3]
# Processed 04_open_circuit_04.jpg - Unique mask values: [0 3]
# Processed 04_open_circuit_19.jpg - Unique mask values: [0 3]
# Processed 04_open_circuit_06.jpg - Unique mask values: [0 3]
# Processed 09_open_circuit_07.jpg - Unique mask values: [0 3]
# Processed 06_open_circuit_08.jpg - Unique mask values: [0 3]
# Processed 09_open_circuit_06.jpg - Unique mask values: [0 3]
# Processed 08_open_circuit_02.jpg - Unique mask values: [0 3]
# Processed 08_open_circuit_01.jpg - Unique mask values: [0 3]
# Processed 07_open_circuit_01.jpg - Unique mask values: [0 3]
# Processed 11_open_circuit_03.jpg - Unique mask values: [0 3]
# Processed 12_open_circuit_04.jpg - Unique mask values: [0 3]
# Processed 08_open_circuit_05.jpg - Unique mask values: [0 3]
# Processed 05_open_circuit_02.jpg - Unique mask values: [0 3]
# Processed 04_open_circuit_10.jpg - Unique mask values: [0 3]
# Processed 05_open_circuit_03.jpg - Unique mask values: [0 3]
# Processed 01_open_circuit_10.jpg - Unique mask values: [0 3]
# Processed 04_open_circuit_16.jpg - Unique mask values: [0 3]
# Processed 12_open_circuit_10.jpg - Unique mask values: [0 3]
# Processed 04_open_circuit_15.jpg - Unique mask values: [0 3]
# Processed 12_open_circuit_01.jpg - Unique mask values: [0 3]
# Processed 05_open_circuit_10.jpg - Unique mask values: [0 3]
# Processed 06_open_circuit_01.jpg - Unique mask values: [0 3]
# Processed 06_open_circuit_02.jpg - Unique mask values: [0 3]
# Processed 01_open_circuit_13.jpg - Unique mask values: [0 3]
# Processed 08_open_circuit_07.jpg - Unique mask values: [0 3]
# Processed 01_open_circuit_16.jpg - Unique mask values: [0 3]
# Processed 01_open_circuit_07.jpg - Unique mask values: [0 3]
# Processed 07_open_circuit_02.jpg - Unique mask values: [0 3]
# Processed 04_open_circuit_13.jpg - Unique mask values: [0 3]
# Processed 10_open_circuit_06.jpg - Unique mask values: [0 3]
# Processed 01_open_circuit_02.jpg - Unique mask values: [0 3]
# Processed 01_open_circuit_19.jpg - Unique mask values: [0 3]
# Processed 08_open_circuit_06.jpg - Unique mask values: [0 3]
# Processed 05_open_circuit_04.jpg - Unique mask values: [0 3]
# Processed 01_open_circuit_04.jpg - Unique mask values: [0 3]
# Processed 09_open_circuit_02.jpg - Unique mask values: [0 3]
# Processed 07_open_circuit_05.jpg - Unique mask values: [0 3]
# Processed 01_open_circuit_15.jpg - Unique mask values: [0 3]
# Processed 12_open_circuit_08.jpg - Unique mask values: [0 3]
# Processed 11_open_circuit_04.jpg - Unique mask values: [0 3]
# Processed 07_open_circuit_10.jpg - Unique mask values: [0 3]
# Processed 12_open_circuit_09.jpg - Unique mask values: [0 3]
# Processed 01_open_circuit_05.jpg - Unique mask values: [0 3]
# Processed 11_open_circuit_07.jpg - Unique mask values: [0 3]
# Processed 11_open_circuit_10.jpg - Unique mask values: [0 3]
# Processed 07_open_circuit_09.jpg - Unique mask values: [0 3]
# Processed 09_open_circuit_08.jpg - Unique mask values: [0 3]
# Processed 01_open_circuit_06.jpg - Unique mask values: [0 3]
# Processed 05_open_circuit_06.jpg - Unique mask values: [0 3]
# Processed 04_open_circuit_02.jpg - Unique mask values: [0 3]
# Processed 06_open_circuit_03.jpg - Unique mask values: [0 3]
# Processed 11_open_circuit_08.jpg - Unique mask values: [0 3]
# Processed 06_open_circuit_06.jpg - Unique mask values: [0 3]
# Processed 11_open_circuit_02.jpg - Unique mask values: [0 3]
# Processed 04_open_circuit_01.jpg - Unique mask values: [0 3]
# Processed 06_open_circuit_04.jpg - Unique mask values: [0 3]
# Processed 08_open_circuit_08.jpg - Unique mask values: [0 3]
# Processed 01_open_circuit_17.jpg - Unique mask values: [0 3]
# Processed 06_open_circuit_07.jpg - Unique mask values: [0 3]
# Processed 05_open_circuit_08.jpg - Unique mask values: [0 3]
# Processed 10_open_circuit_03.jpg - Unique mask values: [0 3]
# Processed 10_open_circuit_05.jpg - Unique mask values: [0 3]
# Processed 09_open_circuit_10.jpg - Unique mask values: [0 3]
# Processed 04_open_circuit_03.jpg - Unique mask values: [0 3]
# Processed 12_open_circuit_03.jpg - Unique mask values: [0 3]
# Processed 09_open_circuit_05.jpg - Unique mask values: [0 3]
# Processed 11_open_circuit_01.jpg - Unique mask values: [0 3]
# Processed 05_open_circuit_09.jpg - Unique mask values: [0 3]
# Processed 04_open_circuit_12.jpg - Unique mask values: [0 3]
# Processed 04_open_circuit_17.jpg - Unique mask values: [0 3]
# Processed 01_open_circuit_12.jpg - Unique mask values: [0 3]
# Processed 04_open_circuit_09.jpg - Unique mask values: [0 3]
# Processed 05_open_circuit_05.jpg - Unique mask values: [0 3]
# Processed 12_open_circuit_06.jpg - Unique mask values: [0 3]
# Processed 01_open_circuit_08.jpg - Unique mask values: [0 3]
# Processed 10_open_circuit_01.jpg - Unique mask values: [0 3]
# Processed 10_open_circuit_02.jpg - Unique mask values: [0 3]
# Processed 01_open_circuit_03.jpg - Unique mask values: [0 3]
# Processed 06_open_circuit_10.jpg - Unique mask values: [0 3]
# Processed 12_open_circuit_02.jpg - Unique mask values: [0 3]
# Processed 01_open_circuit_14.jpg - Unique mask values: [0 3]
# Processed 08_open_circuit_04.jpg - Unique mask values: [0 3]
# Processed 04_open_circuit_05.jpg - Unique mask values: [0 3]
# Processed 01_open_circuit_09.jpg - Unique mask values: [0 3]
# Processed 08_open_circuit_09.jpg - Unique mask values: [0 3]
# Processed 04_open_circuit_08.jpg - Unique mask values: [0 3]
#
# Processing Short...
# Processed 07_short_08.jpg - Unique mask values: [0 4]
# Processed 09_short_07.jpg - Unique mask values: [0 4]
# Processed 09_short_09.jpg - Unique mask values: [0 4]
# Processed 05_short_08.jpg - Unique mask values: [0 4]
# Processed 09_short_05.jpg - Unique mask values: [0 4]
# Processed 01_short_13.jpg - Unique mask values: [0 4]
# Processed 04_short_19.jpg - Unique mask values: [0 4]
# Processed 01_short_03.jpg - Unique mask values: [0 4]
# Processed 06_short_11.jpg - Unique mask values: [0 4]
# Processed 12_short_04.jpg - Unique mask values: [0 4]
# Processed 05_short_05.jpg - Unique mask values: [0 4]
# Processed 09_short_01.jpg - Unique mask values: [0 4]
# Processed 12_short_01.jpg - Unique mask values: [0 4]
# Processed 12_short_08.jpg - Unique mask values: [0 4]
# Processed 01_short_02.jpg - Unique mask values: [0 4]
# Processed 09_short_04.jpg - Unique mask values: [0 4]
# Processed 04_short_08.jpg - Unique mask values: [0 4]
# Processed 12_short_02.jpg - Unique mask values: [0 4]
# Processed 06_short_04.jpg - Unique mask values: [0 4]
# Processed 01_short_10.jpg - Unique mask values: [0 4]
# Processed 08_short_02.jpg - Unique mask values: [0 4]
# Processed 07_short_05.jpg - Unique mask values: [0 4]
# Processed 01_short_11.jpg - Unique mask values: [0 4]
# Processed 08_short_04.jpg - Unique mask values: [0 4]
# Processed 04_short_09.jpg - Unique mask values: [0 4]
# Processed 12_short_07.jpg - Unique mask values: [0 4]
# Processed 01_short_16.jpg - Unique mask values: [0 4]
# Processed 09_short_10.jpg - Unique mask values: [0 4]
# Processed 11_short_05.jpg - Unique mask values: [0 4]
# Processed 08_short_07.jpg - Unique mask values: [0 4]
# Processed 07_short_07.jpg - Unique mask values: [0 4]
# Processed 11_short_07.jpg - Unique mask values: [0 4]
# Processed 11_short_04.jpg - Unique mask values: [0 4]
# Processed 01_short_04.jpg - Unique mask values: [0 4]
# Processed 11_short_06.jpg - Unique mask values: [0 4]
# Processed 06_short_03.jpg - Unique mask values: [0 4]
# Processed 01_short_14.jpg - Unique mask values: [0 4]
# Processed 09_short_02.jpg - Unique mask values: [0 4]
# Processed 05_short_07.jpg - Unique mask values: [0 4]
# Processed 10_short_04.jpg - Unique mask values: [0 4]
# Processed 04_short_03.jpg - Unique mask values: [0 4]
# Processed 07_short_06.jpg - Unique mask values: [0 4]
# Processed 11_short_01.jpg - Unique mask values: [0 4]
# Processed 04_short_05.jpg - Unique mask values: [0 4]
# Processed 07_short_09.jpg - Unique mask values: [0 4]
# Processed 10_short_03.jpg - Unique mask values: [0 4]
# Processed 08_short_09.jpg - Unique mask values: [0 4]
# Processed 05_short_03.jpg - Unique mask values: [0 4]
# Processed 08_short_06.jpg - Unique mask values: [0 4]
# Processed 10_short_01.jpg - Unique mask values: [0 4]
# Processed 04_short_07.jpg - Unique mask values: [0 4]
# Processed 04_short_16.jpg - Unique mask values: [0 4]
# Processed 04_short_14.jpg - Unique mask values: [0 4]
# Processed 01_short_08.jpg - Unique mask values: [0 4]
# Processed 05_short_10.jpg - Unique mask values: [0 4]
# Processed 04_short_13.jpg - Unique mask values: [0 4]
# Processed 08_short_08.jpg - Unique mask values: [0 4]
# Processed 01_short_19.jpg - Unique mask values: [0 4]
# Processed 12_short_10.jpg - Unique mask values: [0 4]
# Processed 12_short_05.jpg - Unique mask values: [0 4]
# Processed 06_short_02.jpg - Unique mask values: [0 4]
# Processed 01_short_15.jpg - Unique mask values: [0 4]
# Processed 10_short_02.jpg - Unique mask values: [0 4]
# Processed 01_short_18.jpg - Unique mask values: [0 4]
# Processed 01_short_07.jpg - Unique mask values: [0 4]
# Processed 05_short_09.jpg - Unique mask values: [0 4]
# Processed 11_short_10.jpg - Unique mask values: [0 4]
# Processed 04_short_20.jpg - Unique mask values: [0 4]
# Processed 12_short_09.jpg - Unique mask values: [0 4]
# Processed 05_short_02.jpg - Unique mask values: [0 4]
# Processed 11_short_03.jpg - Unique mask values: [0 4]
# Processed 08_short_03.jpg - Unique mask values: [0 4]
# Processed 06_short_05.jpg - Unique mask values: [0 4]
# Processed 04_short_10.jpg - Unique mask values: [0 4]
# Processed 04_short_02.jpg - Unique mask values: [0 4]
# Processed 11_short_08.jpg - Unique mask values: [0 4]
# Processed 09_short_08.jpg - Unique mask values: [0 4]
# Processed 07_short_10.jpg - Unique mask values: [0 4]
# Processed 09_short_03.jpg - Unique mask values: [0 4]
# Processed 12_short_06.jpg - Unique mask values: [0 4]
# Processed 04_short_12.jpg - Unique mask values: [0 4]
# Processed 05_short_04.jpg - Unique mask values: [0 4]
# Processed 05_short_06.jpg - Unique mask values: [0 4]
# Processed 07_short_03.jpg - Unique mask values: [0 4]
# Processed 06_short_08.jpg - Unique mask values: [0 4]
# Processed 04_short_17.jpg - Unique mask values: [0 4]
# Processed 07_short_01.jpg - Unique mask values: [0 4]
# Processed 01_short_09.jpg - Unique mask values: [0 4]
# Processed 06_short_09.jpg - Unique mask values: [0 4]
# Processed 01_short_17.jpg - Unique mask values: [0 4]
# Processed 04_short_01.jpg - Unique mask values: [0 4]
# Processed 06_short_10.jpg - Unique mask values: [0 4]
# Processed 09_short_06.jpg - Unique mask values: [0 4]
# Processed 01_short_12.jpg - Unique mask values: [0 4]
# Processed 04_short_06.jpg - Unique mask values: [0 4]
# Processed 07_short_02.jpg - Unique mask values: [0 4]
# Processed 07_short_04.jpg - Unique mask values: [0 4]
# Processed 01_short_01.jpg - Unique mask values: [0 4]
# Processed 01_short_20.jpg - Unique mask values: [0 4]
# Processed 04_short_15.jpg - Unique mask values: [0 4]
# Processed 05_short_01.jpg - Unique mask values: [0 4]
# Processed 04_short_04.jpg - Unique mask values: [0 4]
# Processed 04_short_11.jpg - Unique mask values: [0 4]
# Processed 11_short_09.jpg - Unique mask values: [0 4]
# Processed 10_short_05.jpg - Unique mask values: [0 4]
# Processed 12_short_03.jpg - Unique mask values: [0 4]
# Processed 08_short_10.jpg - Unique mask values: [0 4]
# Processed 01_short_05.jpg - Unique mask values: [0 4]
# Processed 11_short_02.jpg - Unique mask values: [0 4]
# Processed 06_short_07.jpg - Unique mask values: [0 4]
# Processed 06_short_01.jpg - Unique mask values: [0 4]
# Processed 04_short_18.jpg - Unique mask values: [0 4]
# Processed 06_short_06.jpg - Unique mask values: [0 4]
# Processed 08_short_01.jpg - Unique mask values: [0 4]
# Processed 01_short_06.jpg - Unique mask values: [0 4]
# Processed 08_short_05.jpg - Unique mask values: [0 4]
#
# Processing Spur...
# Processed 10_spur_03.jpg - Unique mask values: [0 5]
# Processed 06_spur_02.jpg - Unique mask values: [0 5]
# Processed 08_spur_01.jpg - Unique mask values: [0 5]
# Processed 04_spur_06.jpg - Unique mask values: [0 5]
# Processed 11_spur_07.jpg - Unique mask values: [0 5]
# Processed 04_spur_12.jpg - Unique mask values: [0 5]
# Processed 12_spur_07.jpg - Unique mask values: [0 5]
# Processed 01_spur_04.jpg - Unique mask values: [0 5]
# Processed 01_spur_18.jpg - Unique mask values: [0 5]
# Processed 11_spur_01.jpg - Unique mask values: [0 5]
# Processed 06_spur_06.jpg - Unique mask values: [0 5]
# Processed 05_spur_09.jpg - Unique mask values: [0 5]
# Processed 07_spur_02.jpg - Unique mask values: [0 5]
# Processed 01_spur_05.jpg - Unique mask values: [0 5]
# Processed 04_spur_04.jpg - Unique mask values: [0 5]
# Processed 07_spur_09.jpg - Unique mask values: [0 5]
# Processed 07_spur_10.jpg - Unique mask values: [0 5]
# Processed 12_spur_06.jpg - Unique mask values: [0 5]
# Processed 05_spur_04.jpg - Unique mask values: [0 5]
# Processed 05_spur_07.jpg - Unique mask values: [0 5]
# Processed 04_spur_05.jpg - Unique mask values: [0 5]
# Processed 04_spur_13.jpg - Unique mask values: [0 5]
# Processed 01_spur_09.jpg - Unique mask values: [0 5]
# Processed 01_spur_03.jpg - Unique mask values: [0 5]
# Processed 01_spur_17.jpg - Unique mask values: [0 5]
# Processed 09_spur_05.jpg - Unique mask values: [0 5]
# Processed 01_spur_19.jpg - Unique mask values: [0 5]
# Processed 09_spur_09.jpg - Unique mask values: [0 5]
# Processed 04_spur_19.jpg - Unique mask values: [0 5]
# Processed 06_spur_08.jpg - Unique mask values: [0 5]
# Processed 11_spur_03.jpg - Unique mask values: [0 5]
# Processed 09_spur_02.jpg - Unique mask values: [0 5]
# Processed 08_spur_03.jpg - Unique mask values: [0 5]
# Processed 09_spur_06.jpg - Unique mask values: [0 5]
# Processed 12_spur_01.jpg - Unique mask values: [0 5]
# Processed 09_spur_01.jpg - Unique mask values: [0 5]
# Processed 08_spur_07.jpg - Unique mask values: [0 5]
# Processed 12_spur_08.jpg - Unique mask values: [0 5]
# Processed 10_spur_01.jpg - Unique mask values: [0 5]
# Processed 12_spur_04.jpg - Unique mask values: [0 5]
# Processed 05_spur_05.jpg - Unique mask values: [0 5]
# Processed 01_spur_16.jpg - Unique mask values: [0 5]
# Processed 04_spur_03.jpg - Unique mask values: [0 5]
# Processed 09_spur_08.jpg - Unique mask values: [0 5]
# Processed 04_spur_11.jpg - Unique mask values: [0 5]
# Processed 04_spur_02.jpg - Unique mask values: [0 5]
# Processed 09_spur_03.jpg - Unique mask values: [0 5]
# Processed 06_spur_05.jpg - Unique mask values: [0 5]
# Processed 09_spur_07.jpg - Unique mask values: [0 5]
# Processed 05_spur_10.jpg - Unique mask values: [0 5]
# Processed 11_spur_09.jpg - Unique mask values: [0 5]
# Processed 08_spur_08.jpg - Unique mask values: [0 5]
# Processed 11_spur_10.jpg - Unique mask values: [0 5]
# Processed 04_spur_14.jpg - Unique mask values: [0 5]
# Processed 07_spur_05.jpg - Unique mask values: [0 5]
# Processed 10_spur_05.jpg - Unique mask values: [0 5]
# Processed 12_spur_09.jpg - Unique mask values: [0 5]
# Processed 05_spur_02.jpg - Unique mask values: [0 5]
# Processed 06_spur_07.jpg - Unique mask values: [0 5]
# Processed 11_spur_05.jpg - Unique mask values: [0 5]
# Processed 10_spur_04.jpg - Unique mask values: [0 5]
# Processed 01_spur_06.jpg - Unique mask values: [0 5]
# Processed 08_spur_04.jpg - Unique mask values: [0 5]
# Processed 01_spur_20.jpg - Unique mask values: [0 5]
# Processed 04_spur_17.jpg - Unique mask values: [0 5]
# Processed 12_spur_10.jpg - Unique mask values: [0 5]
# Processed 04_spur_15.jpg - Unique mask values: [0 5]
# Processed 12_spur_03.jpg - Unique mask values: [0 5]
# Processed 07_spur_06.jpg - Unique mask values: [0 5]
# Processed 01_spur_07.jpg - Unique mask values: [0 5]
# Processed 04_spur_09.jpg - Unique mask values: [0 5]
# Processed 04_spur_07.jpg - Unique mask values: [0 5]
# Processed 04_spur_10.jpg - Unique mask values: [0 5]
# Processed 04_spur_18.jpg - Unique mask values: [0 5]
# Processed 10_spur_02.jpg - Unique mask values: [0 5]
# Processed 09_spur_10.jpg - Unique mask values: [0 5]
# Processed 08_spur_10.jpg - Unique mask values: [0 5]
# Processed 07_spur_03.jpg - Unique mask values: [0 5]
# Processed 05_spur_03.jpg - Unique mask values: [0 5]
# Processed 01_spur_10.jpg - Unique mask values: [0 5]
# Processed 01_spur_12.jpg - Unique mask values: [0 5]
# Processed 04_spur_08.jpg - Unique mask values: [0 5]
# Processed 11_spur_06.jpg - Unique mask values: [0 5]
# Processed 01_spur_08.jpg - Unique mask values: [0 5]
# Processed 07_spur_04.jpg - Unique mask values: [0 5]
# Processed 01_spur_11.jpg - Unique mask values: [0 5]
# Processed 06_spur_09.jpg - Unique mask values: [0 5]
# Processed 08_spur_09.jpg - Unique mask values: [0 5]
# Processed 05_spur_01.jpg - Unique mask values: [0 5]
# Processed 07_spur_01.jpg - Unique mask values: [0 5]
# Processed 08_spur_06.jpg - Unique mask values: [0 5]
# Processed 01_spur_01.jpg - Unique mask values: [0 5]
# Processed 09_spur_04.jpg - Unique mask values: [0 5]
# Processed 11_spur_08.jpg - Unique mask values: [0 5]
# Processed 07_spur_07.jpg - Unique mask values: [0 5]
# Processed 06_spur_01.jpg - Unique mask values: [0 5]
# Processed 08_spur_02.jpg - Unique mask values: [0 5]
# Processed 01_spur_15.jpg - Unique mask values: [0 5]
# Processed 12_spur_02.jpg - Unique mask values: [0 5]
# Processed 07_spur_08.jpg - Unique mask values: [0 5]
# Processed 05_spur_08.jpg - Unique mask values: [0 5]
# Processed 11_spur_04.jpg - Unique mask values: [0 5]
# Processed 01_spur_13.jpg - Unique mask values: [0 5]
# Processed 06_spur_04.jpg - Unique mask values: [0 5]
# Processed 05_spur_06.jpg - Unique mask values: [0 5]
# Processed 01_spur_02.jpg - Unique mask values: [0 5]
# Processed 01_spur_14.jpg - Unique mask values: [0 5]
# Processed 04_spur_01.jpg - Unique mask values: [0 5]
# Processed 11_spur_02.jpg - Unique mask values: [0 5]
# Processed 12_spur_05.jpg - Unique mask values: [0 5]
# Processed 08_spur_05.jpg - Unique mask values: [0 5]
# Processed 04_spur_16.jpg - Unique mask values: [0 5]
# Processed 04_spur_20.jpg - Unique mask values: [0 5]
# Processed 06_spur_03.jpg - Unique mask values: [0 5]
# Processed 06_spur_10.jpg - Unique mask values: [0 5]
#
# Processing Spurious_copper...
# Processed 05_spurious_copper_02.jpg - Unique mask values: [0 6]
# Processed 12_spurious_copper_09.jpg - Unique mask values: [0 6]
# Processed 11_spurious_copper_03.jpg - Unique mask values: [0 6]
# Processed 01_spurious_copper_04.jpg - Unique mask values: [0 6]
# Processed 12_spurious_copper_08.jpg - Unique mask values: [0 6]
# Processed 09_spurious_copper_08.jpg - Unique mask values: [0 6]
# Processed 01_spurious_copper_10.jpg - Unique mask values: [0 6]
# Processed 12_spurious_copper_04.jpg - Unique mask values: [0 6]
# Processed 08_spurious_copper_02.jpg - Unique mask values: [0 6]
# Processed 11_spurious_copper_09.jpg - Unique mask values: [0 6]
# Processed 05_spurious_copper_04.jpg - Unique mask values: [0 6]
# Processed 05_spurious_copper_03.jpg - Unique mask values: [0 6]
# Processed 08_spurious_copper_08.jpg - Unique mask values: [0 6]
# Processed 11_spurious_copper_04.jpg - Unique mask values: [0 6]
# Processed 10_spurious_copper_02.jpg - Unique mask values: [0 6]
# Processed 04_spurious_copper_01.jpg - Unique mask values: [0 6]
# Processed 05_spurious_copper_06.jpg - Unique mask values: [0 6]
# Processed 01_spurious_copper_16.jpg - Unique mask values: [0 6]
# Processed 07_spurious_copper_04.jpg - Unique mask values: [0 6]
# Processed 07_spurious_copper_02.jpg - Unique mask values: [0 6]
# Processed 08_spurious_copper_07.jpg - Unique mask values: [0 6]
# Processed 04_spurious_copper_17.jpg - Unique mask values: [0 6]
# Processed 12_spurious_copper_02.jpg - Unique mask values: [0 6]
# Processed 06_spurious_copper_07.jpg - Unique mask values: [0 6]
# Processed 11_spurious_copper_10.jpg - Unique mask values: [0 6]
# Processed 08_spurious_copper_06.jpg - Unique mask values: [0 6]
# Processed 06_spurious_copper_08.jpg - Unique mask values: [0 6]
# Processed 01_spurious_copper_01.jpg - Unique mask values: [0 6]
# Processed 11_spurious_copper_07.jpg - Unique mask values: [0 6]
# Processed 05_spurious_copper_05.jpg - Unique mask values: [0 6]
# Processed 09_spurious_copper_09.jpg - Unique mask values: [0 6]
# Processed 04_spurious_copper_06.jpg - Unique mask values: [0 6]
# Processed 04_spurious_copper_03.jpg - Unique mask values: [0 6]
# Processed 07_spurious_copper_03.jpg - Unique mask values: [0 6]
# Processed 08_spurious_copper_04.jpg - Unique mask values: [0 6]
# Processed 06_spurious_copper_06.jpg - Unique mask values: [0 6]
# Processed 10_spurious_copper_03.jpg - Unique mask values: [0 6]
# Processed 06_spurious_copper_09.jpg - Unique mask values: [0 6]
# Processed 01_spurious_copper_15.jpg - Unique mask values: [0 6]
# Processed 04_spurious_copper_09.jpg - Unique mask values: [0 6]
# Processed 09_spurious_copper_03.jpg - Unique mask values: [0 6]
# Processed 04_spurious_copper_11.jpg - Unique mask values: [0 6]
# Processed 04_spurious_copper_05.jpg - Unique mask values: [0 6]
# Processed 05_spurious_copper_08.jpg - Unique mask values: [0 6]
# Processed 05_spurious_copper_01.jpg - Unique mask values: [0 6]
# Processed 08_spurious_copper_03.jpg - Unique mask values: [0 6]
# Processed 09_spurious_copper_02.jpg - Unique mask values: [0 6]
# Processed 11_spurious_copper_08.jpg - Unique mask values: [0 6]
# Processed 07_spurious_copper_08.jpg - Unique mask values: [0 6]
# Processed 08_spurious_copper_01.jpg - Unique mask values: [0 6]
# Processed 01_spurious_copper_20.jpg - Unique mask values: [0 6]
# Processed 12_spurious_copper_01.jpg - Unique mask values: [0 6]
# Processed 04_spurious_copper_08.jpg - Unique mask values: [0 6]
# Processed 12_spurious_copper_03.jpg - Unique mask values: [0 6]
# Processed 11_spurious_copper_05.jpg - Unique mask values: [0 6]
# Processed 04_spurious_copper_20.jpg - Unique mask values: [0 6]
# Processed 12_spurious_copper_05.jpg - Unique mask values: [0 6]
# Processed 10_spurious_copper_06.jpg - Unique mask values: [0 6]
# Processed 05_spurious_copper_07.jpg - Unique mask values: [0 6]
# Processed 09_spurious_copper_05.jpg - Unique mask values: [0 6]
# Processed 01_spurious_copper_12.jpg - Unique mask values: [0 6]
# Processed 09_spurious_copper_01.jpg - Unique mask values: [0 6]
# Processed 01_spurious_copper_06.jpg - Unique mask values: [0 6]
# Processed 04_spurious_copper_12.jpg - Unique mask values: [0 6]
# Processed 12_spurious_copper_07.jpg - Unique mask values: [0 6]
# Processed 12_spurious_copper_06.jpg - Unique mask values: [0 6]
# Processed 01_spurious_copper_02.jpg - Unique mask values: [0 6]
# Processed 11_spurious_copper_01.jpg - Unique mask values: [0 6]
# Processed 04_spurious_copper_19.jpg - Unique mask values: [0 6]
# Processed 01_spurious_copper_09.jpg - Unique mask values: [0 6]
# Processed 06_spurious_copper_04.jpg - Unique mask values: [0 6]
# Processed 01_spurious_copper_17.jpg - Unique mask values: [0 6]
# Processed 01_spurious_copper_05.jpg - Unique mask values: [0 6]
# Processed 09_spurious_copper_07.jpg - Unique mask values: [0 6]
# Processed 01_spurious_copper_13.jpg - Unique mask values: [0 6]
# Processed 11_spurious_copper_02.jpg - Unique mask values: [0 6]
# Processed 05_spurious_copper_10.jpg - Unique mask values: [0 6]
# Processed 06_spurious_copper_05.jpg - Unique mask values: [0 6]
# Processed 05_spurious_copper_09.jpg - Unique mask values: [0 6]
# Processed 04_spurious_copper_14.jpg - Unique mask values: [0 6]
# Processed 08_spurious_copper_09.jpg - Unique mask values: [0 6]
# Processed 04_spurious_copper_04.jpg - Unique mask values: [0 6]
# Processed 10_spurious_copper_01.jpg - Unique mask values: [0 6]
# Processed 06_spurious_copper_01.jpg - Unique mask values: [0 6]
# Processed 01_spurious_copper_07.jpg - Unique mask values: [0 6]
# Processed 04_spurious_copper_07.jpg - Unique mask values: [0 6]
# Processed 06_spurious_copper_02.jpg - Unique mask values: [0 6]
# Processed 10_spurious_copper_05.jpg - Unique mask values: [0 6]
# Processed 07_spurious_copper_06.jpg - Unique mask values: [0 6]
# Processed 01_spurious_copper_19.jpg - Unique mask values: [0 6]
# Processed 08_spurious_copper_05.jpg - Unique mask values: [0 6]
# Processed 07_spurious_copper_05.jpg - Unique mask values: [0 6]
# Processed 10_spurious_copper_04.jpg - Unique mask values: [0 6]
# Processed 07_spurious_copper_09.jpg - Unique mask values: [0 6]
# Processed 04_spurious_copper_10.jpg - Unique mask values: [0 6]
# Processed 04_spurious_copper_15.jpg - Unique mask values: [0 6]
# Processed 01_spurious_copper_08.jpg - Unique mask values: [0 6]
# Processed 07_spurious_copper_10.jpg - Unique mask values: [0 6]
# Processed 01_spurious_copper_11.jpg - Unique mask values: [0 6]
# Processed 01_spurious_copper_14.jpg - Unique mask values: [0 6]
# Processed 06_spurious_copper_10.jpg - Unique mask values: [0 6]
# Processed 09_spurious_copper_04.jpg - Unique mask values: [0 6]
# Processed 09_spurious_copper_06.jpg - Unique mask values: [0 6]
# Processed 08_spurious_copper_10.jpg - Unique mask values: [0 6]
# Processed 04_spurious_copper_13.jpg - Unique mask values: [0 6]
# Processed 07_spurious_copper_01.jpg - Unique mask values: [0 6]
# Processed 04_spurious_copper_18.jpg - Unique mask values: [0 6]
# Processed 04_spurious_copper_16.jpg - Unique mask values: [0 6]
# Processed 06_spurious_copper_03.jpg - Unique mask values: [0 6]
# Processed 09_spurious_copper_10.jpg - Unique mask values: [0 6]
# Processed 01_spurious_copper_18.jpg - Unique mask values: [0 6]
# Processed 04_spurious_copper_02.jpg - Unique mask values: [0 6]
# Processed 12_spurious_copper_10.jpg - Unique mask values: [0 6]
# Processed 07_spurious_copper_07.jpg - Unique mask values: [0 6]
# Processed 11_spurious_copper_06.jpg - Unique mask values: [0 6]
# Processed 01_spurious_copper_03.jpg - Unique mask values: [0 6]
